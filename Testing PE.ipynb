# %%
# !pip install mediapipe
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.6/35.6 MB 56.1 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Import Required Libraries
# Import the necessary libraries, including Mediapipe, dlib, and other relevant libraries.

# %%
# Import Required Libraries
import os
import torch
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
from PIL import Image
import matplotlib.pyplot as plt
import mediapipe as mp
import dlib
import time
import numpy as np
import cv2

# Check if GPU is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %% [markdown]
# # Compare Mediapipe and dlib
# Compare Mediapipe and dlib for accuracy, processing speed, and ease of integration with SDXL workflows.

# %%
# Compare Mediapipe and dlib

# Load sample image
image_path = '/content/Sample_images/1_0_0_20161219194756275.jpg'
image = Image.open(image_path)
image_np = np.array(image)

# Mediapipe face detection
mp_face_detection = mp.solutions.face_detection
mp_drawing = mp.solutions.drawing_utils

with mp_face_detection.FaceDetection(model_selection=1, min_detection_confidence=0.5) as face_detection:
    start_time = time.time()
    results = face_detection.process(image_np)
    mediapipe_time = time.time() - start_time

    if results.detections:
        for detection in results.detections:
            mp_drawing.draw_detection(image_np, detection)

# Display Mediapipe results
plt.imshow(image_np)
plt.title('Mediapipe Face Detection')
plt.show()

# Dlib face detection
detector = dlib.get_frontal_face_detector()

start_time = time.time()
dlib_faces = detector(image_np, 1)
dlib_time = time.time() - start_time

# Draw rectangles around detected faces
for face in dlib_faces:
    x, y, w, h = (face.left(), face.top(), face.width(), face.height())
    cv2.rectangle(image_np, (x, y), (x + w, y + h), (255, 0, 0), 2)

# Display Dlib results
plt.imshow(image_np)
plt.title('Dlib Face Detection')
plt.show()

# Print processing times
print(f"Mediapipe processing time: {mediapipe_time:.4f} seconds")
print(f"Dlib processing time: {dlib_time:.4f} seconds")
# Out:
# Mediapipe processing time: 0.0234 seconds
# Dlib processing time: 0.0934 seconds

# %% [markdown]
# # Integrate Face Detection Tools
# Integrate Mediapipe and dlib into the SDXL workflow.

# %%
# Integrate Mediapipe and dlib into the SDXL workflow

# Import Required Libraries
import os
import torch
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
from PIL import Image
import matplotlib.pyplot as plt
import mediapipe as mp
import dlib
import time
import numpy as np
import cv2

# Check if GPU is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Load sample image
image_path = '/content/Sample_images/1_0_0_20161219194756275.jpg'
image = Image.open(image_path)
image_np = np.array(image)

# Mediapipe face detection
mp_face_detection = mp.solutions.face_detection
mp_drawing = mp.solutions.drawing_utils

with mp_face_detection.FaceDetection(model_selection=1, min_detection_confidence=0.5) as face_detection:
    start_time = time.time()
    results = face_detection.process(image_np)
    mediapipe_time = time.time() - start_time

    if results.detections:
        for detection in results.detections:
            mp_drawing.draw_detection(image_np, detection)

# Display Mediapipe results
plt.imshow(image_np)
plt.title('Mediapipe Face Detection')
plt.show()

# Dlib face detection
detector = dlib.get_frontal_face_detector()

start_time = time.time()
dlib_faces = detector(image_np, 1)
dlib_time = time.time() - start_time

# Draw rectangles around detected faces
for face in dlib_faces:
    x, y, w, h = (face.left(), face.top(), face.width(), face.height())
    cv2.rectangle(image_np, (x, y), (x + w, y + h), (255, 0, 0), 2)

# Display Dlib results
plt.imshow(image_np)
plt.title('Dlib Face Detection')
plt.show()

# Print processing times
print(f"Mediapipe processing time: {mediapipe_time:.4f} seconds")
print(f"Dlib processing time: {dlib_time:.4f} seconds")
# Out:
# Using device: cuda
# Mediapipe processing time: 0.0360 seconds
# Dlib processing time: 0.1294 seconds

# %% [markdown]
# # Verify System Compatibility
# Verify system compatibility and confirm baseline functionality for the experimental setup.

# %%
# Verify System Compatibility

# Check if Mediapipe is installed
try:
    import mediapipe as mp
    print("Mediapipe is installed.")
except ImportError:
    print("Mediapipe is not installed. Please install it using 'pip install mediapipe'.")

# Check if dlib is installed
try:
    import dlib
    print("dlib is installed.")
except ImportError:
    print("dlib is not installed. Please install it using 'pip install dlib'.")

# Check if OpenCV is installed
try:
    import cv2
    print("OpenCV is installed.")
except ImportError:
    print("OpenCV is not installed. Please install it using 'pip install opencv-python'.")

# Check if PIL is installed
try:
    from PIL import Image
    print("PIL is installed.")
except ImportError:
    print("PIL is not installed. Please install it using 'pip install pillow'.")

# Check if torch is installed
try:
    import torch
    print("PyTorch is installed.")
except ImportError:
    print("PyTorch is not installed. Please install it using 'pip install torch'.")

# Check if GPU is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Load a sample image to verify PIL and OpenCV functionality
image_path = '/content/Sample_images/1_0_0_20161219194756275.jpg'
try:
    image = Image.open(image_path)
    image_np = np.array(image)
    print("Sample image loaded successfully.")
except Exception as e:
    print(f"Error loading sample image: {e}")

# Verify Mediapipe face detection
try:
    mp_face_detection = mp.solutions.face_detection
    with mp_face_detection.FaceDetection(model_selection=1, min_detection_confidence=0.5) as face_detection:
        results = face_detection.process(image_np)
    print("Mediapipe face detection verified.")
except Exception as e:
    print(f"Error verifying Mediapipe face detection: {e}")

# Verify dlib face detection
try:
    detector = dlib.get_frontal_face_detector()
    dlib_faces = detector(image_np, 1)
    print("dlib face detection verified.")
except Exception as e:
    print(f"Error verifying dlib face detection: {e}")
# Out:
# Mediapipe is installed.
# dlib is installed.
# OpenCV is installed.
# PIL is installed.
# PyTorch is installed.
# Using device: cuda
# Sample image loaded successfully.
# Mediapipe face detection verified.
# dlib face detection verified.

# %% [markdown]
# # Process Sample Images
# Process sample images to evaluate system efficiency and output quality at varying resolutions.

# %%
# Process Sample Images

# Function to process images at varying resolutions
def process_image_at_resolutions(image_path, resolutions):
    original_image = Image.open(image_path)
    results = []

    for resolution in resolutions:
        # Resize image
        resized_image = original_image.resize(resolution)
        image_np = np.array(resized_image)

        # Mediapipe face detection
        with mp_face_detection.FaceDetection(model_selection=1, min_detection_confidence=0.5) as face_detection:
            start_time = time.time()
            results_mediapipe = face_detection.process(image_np)
            mediapipe_time = time.time() - start_time

        # Dlib face detection
        start_time = time.time()
        dlib_faces = detector(image_np, 1)
        dlib_time = time.time() - start_time

        # Store results
        results.append({
            'resolution': resolution,
            'mediapipe_time': mediapipe_time,
            'dlib_time': dlib_time,
            'mediapipe_detections': len(results_mediapipe.detections) if results_mediapipe.detections else 0,
            'dlib_detections': len(dlib_faces)
        })

    return results

# Define resolutions to test
resolutions = [(640, 480), (1280, 720), (1920, 1080)]

# Process the sample image at different resolutions
image_path = '/content/Sample_images/1_0_0_20161219194756275.jpg'
results = process_image_at_resolutions(image_path, resolutions)

# Display results
for result in results:
    print(f"Resolution: {result['resolution']}")
    print(f"Mediapipe processing time: {result['mediapipe_time']:.4f} seconds, Detections: {result['mediapipe_detections']}")
    print(f"Dlib processing time: {result['dlib_time']:.4f} seconds, Detections: {result['dlib_detections']}")
    print()
# Out:
# Resolution: (640, 480)
# Mediapipe processing time: 0.0215 seconds, Detections: 1
# Dlib processing time: 0.1678 seconds, Detections: 1
#
# Resolution: (1280, 720)
# Mediapipe processing time: 0.0328 seconds, Detections: 1
# Dlib processing time: 0.5036 seconds, Detections: 1
#
# Resolution: (1920, 1080)
# Mediapipe processing time: 0.0225 seconds, Detections: 1
# Dlib processing time: 1.1396 seconds, Detections: 1

# %% [markdown]
# # Identify Slowdowns in Pipelines
# Identify slowdowns in face detection and integration pipelines during high-resolution editing.

# %%
# Identify Slowdowns in Pipelines

# Function to identify slowdowns in face detection and integration pipelines
def identify_slowdowns(image_path, resolutions):
    original_image = Image.open(image_path)
    slowdown_results = []

    for resolution in resolutions:
        # Resize image
        resized_image = original_image.resize(resolution)
        image_np = np.array(resized_image)

        # Mediapipe face detection
        with mp_face_detection.FaceDetection(model_selection=1, min_detection_confidence=0.5) as face_detection:
            start_time = time.time()
            results_mediapipe = face_detection.process(image_np)
            mediapipe_time = time.time() - start_time

        # Dlib face detection
        start_time = time.time()
        dlib_faces = detector(image_np, 1)
        dlib_time = time.time() - start_time

        # Store results
        slowdown_results.append({
            'resolution': resolution,
            'mediapipe_time': mediapipe_time,
            'dlib_time': dlib_time,
            'mediapipe_detections': len(results_mediapipe.detections) if results_mediapipe.detections else 0,
            'dlib_detections': len(dlib_faces)
        })

    return slowdown_results

# Define resolutions to test
resolutions = [(640, 480), (1280, 720), (1920, 1080), (3840, 2160)]

# Identify slowdowns in the sample image at different resolutions
image_path = '/content/Sample_images/1_0_0_20161219194756275.jpg'
slowdown_results = identify_slowdowns(image_path, resolutions)

# Display slowdown results
for result in slowdown_results:
    print(f"Resolution: {result['resolution']}")
    print(f"Mediapipe processing time: {result['mediapipe_time']:.4f} seconds, Detections: {result['mediapipe_detections']}")
    print(f"Dlib processing time: {result['dlib_time']:.4f} seconds, Detections: {result['dlib_detections']}")
    print()
# Out:
# Resolution: (640, 480)
# Mediapipe processing time: 0.0216 seconds, Detections: 1
# Dlib processing time: 0.1648 seconds, Detections: 1
#
# Resolution: (1280, 720)
# Mediapipe processing time: 0.0329 seconds, Detections: 1
# Dlib processing time: 0.5493 seconds, Detections: 1
#
# Resolution: (1920, 1080)
# Mediapipe processing time: 0.0211 seconds, Detections: 1
# Dlib processing time: 1.0911 seconds, Detections: 1
#
# Resolution: (3840, 2160)
# Mediapipe processing time: 0.0245 seconds, Detections: 1
# Dlib processing time: 4.5288 seconds, Detections: 1
